# %% [markdown]
# # Presentation of some basic features

# %% [markdown]
# ## Plotting two inequalities (with their intersection highlighted)

# %%
from PIE.plotter import plot_algebraic_problem_3D

def expr_1(x, y, z):
    return (x >= 10) & (y <= 20)

def expr_2(x, y, z):
    return z <= 30

plot_algebraic_problem_3D(
    expressions=[expr_1, expr_2],
    domain=(0, 50),
    plot_intersection_only=False
)

# %%
from PIE.plotter import plot_algebraic_problem_3D

def expr_1(x, y, z):
    return (x >= 10) & (y <= 20)

def expr_2(x, y, z):
    return z <= 30

plot_algebraic_problem_3D(
    expressions=[expr_1, expr_2],
    domain=(0, 50),
    plot_intersection_only=False,
    view_init=(0, 90)
)

# %%
from PIE.plotter import plot_algebraic_problem_3D

def expr_1(x, y, z):
    return (x >= 10) & (y <= 20)

def expr_2(x, y, z):
    return z <= 30

plot_algebraic_problem_3D(
    expressions=[expr_1, expr_2],
    domain=(0, 50),
    plot_intersection_only=False,
    view_init=(50, 50)
)

# %% [markdown]
# eq_1 is the blue and red region.
# eq_2 is the orange and red region.
# The red area is the region where both equations are intersecting.

# %% [markdown]
# ## Unfortunately the plot is misaligned at x=0. This is a visualization artifact caused by matplotlib. They say rotation can helps sometimes. Let's set another viewing angle.

# %%
plot_algebraic_problem_3D(
    expressions=[expr_1, expr_2],
    domain=(0, 50),
    plot_intersection_only=False,
    view_init=(30, -100)
)

# %% [markdown]
# ## Now it's misaligned at x=50 instead of x=0. Let us just hide the ticks on the axis...

# %%
plot_algebraic_problem_3D(
    expressions=[expr_1, expr_2],
    domain=(0, 50),
    plot_intersection_only=False,
    view_init=(30,-100),
    hide_ticks=True
)

# %% [markdown]
# ## Let us save this very cool plot!

# %%
plot_algebraic_problem_3D(
    expressions=[expr_1, expr_2],
    domain=(0, 50),
    plot_intersection_only=False,
    view_init=(30,-100),
    hide_ticks=True,
    save_fig = './my_very_cool_plot.png'
)

# %% [markdown]
# ## If you only want to see the intersection you can do that also. Just set plot_intersection_only to True

# %%
plot_algebraic_problem_3D(
    expressions=[expr_1, expr_2],
    domain=(0, 50),
    plot_intersection_only=True
)

# %% [markdown]
# # Let's plot some more interesting inequalities!

# %%
from PIE.plotter import plot_algebraic_problem_3D

def expr_1(x, y, z):
    return 2*x + 3*y + 4*z <= 6

def expr_2(x, y, z):
    return z <= (3/2) - (1/2)*x - (3/4)*y

plot_algebraic_problem_3D(
    expressions=[expr_1, expr_2],
    domain=(0, 5),
    plot_intersection_only=False
)

# %% [markdown]
# ## Let's make the resolution higher!

# %%
plot_algebraic_problem_3D(
    expressions=[expr_1, expr_2],
    domain=(0, 5),
    plot_intersection_only=False,
    resolution=20
)

# %% [markdown]
# ## Looks much better. Already noticed that we only got an intersection even with plot_intersection_only set to False? Maybe both inequalities are equivalent... Let's have a look at the seperate inequalities

# %%
plot_algebraic_problem_3D(
    expressions=[expr_1],
    domain=(0, 5),
    plot_intersection_only=False,
    resolution=20
)

# %%
plot_algebraic_problem_3D(
    expressions=[expr_2],
    domain=(0, 5),
    plot_intersection_only=False,
    resolution=20
)

# %% [markdown]
# Considering the plot alone, we cannot guarantee the equivalence of both inequalities as there may be a possibility of splitting in a region that is not plotted, such as for negative x values. But fortunately we still have traditional mathematics to prove that both inequalities are equivalent.
#
# We can start by rearranging the inequality 2x + 3y + 4z ≤ 6 as 4z ≤ 6 - 2x - 3y.
# Then, we can divide both sides of the inequality by 4 to get z ≤ (6 - 2x - 3y)/4.
# Simplifying this expression, we get z ≤ (3/2) - (1/2)*x - (3/4)*y, which is the other inequality.
#
# Therefore, the two inequalities are equivalent, meaning that they have the same solutions for x, y, and z that satisfy the inequality.
